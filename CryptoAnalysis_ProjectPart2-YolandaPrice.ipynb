# %% [markdown]
# # Reading in historical data of each Forex currency being traded and sold within the global trade market

# %%
import pandas as pd

# %% [markdown]
# # Japanese Yen

# %%
USDollartoJapaneseYen = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Forex History Data 2/USDJPY-2000-2020-15m.csv")

# %%
USDollartoJapaneseYen1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Data 4/USDJPY-H1.csv")

# %%
USDollartoJapaneseYen.head()
# Out:
#              DATE_TIME    HIGH     LOW    OPEN   CLOSE
# 0  2000.01.03 00:00:00  102.15  102.12  102.14  102.14
# 1  2000.01.03 00:15:00  102.26  102.13  102.15  102.26
# 2  2000.01.03 00:30:00  102.17  102.14  102.15  102.15
# 3  2000.01.03 00:45:00  102.20  102.12  102.16  102.20
# 4  2000.01.03 01:00:00  102.22  102.12  102.20  102.12

# %%
USDollartoJapaneseYen1.head()
# Out:
#          Date      Time  OpenBid  HighBid  LowBid  CloseBid  OpenAsk  HighAsk  \
# 0  01/03/2010  22:00:00   93.075   93.090  92.879    92.920   93.093   93.101
# 1  01/03/2010  23:00:00   92.920   93.008  92.686    92.735   92.940   93.025
# 2  01/04/2010  00:00:00   92.735   92.958  92.735    92.889   92.752   92.971
# 3  01/04/2010  01:00:00   92.889   93.069  92.885    92.975   92.903   93.084
# 4  01/04/2010  02:00:00   92.975   92.975  92.837    92.866   92.987   92.987
#
#    LowAsk  CloseAsk  Total Ticks
# 0  92.895    92.940          674
# 1  92.704    92.752         1751
# 2  92.752    92.903         2987
# 3  92.900    92.987         2248
# 4  92.854    92.883         2551

# %% [markdown]
# # Chinese Kwan

# %%
USDollartoChineseKwan = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/RprtRateXchg_20210930_20210930.csv")
USDollartoChineseKwan.head()
# Out:
#   Record Date            Country             Currency  \
# 0  2021-09-30        Afghanistan              Afghani
# 1  2021-09-30            Albania                  Lek
# 2  2021-09-30            Algeria                Dinar
# 3  2021-09-30             Angola               Kwanza
# 4  2021-09-30  Antigua & Barbuda  E. Caribbean Dollar
#
#           Country - Currency Description  Exchange Rate Effective Date  \
# 0                    Afghanistan-Afghani          87.88     2021-09-30
# 1                            Albania-Lek         104.80     2021-09-30
# 2                          Algeria-Dinar         136.61     2021-09-30
# 3                          Angola-Kwanza         598.65     2021-09-30
# 4  Antigua & Barbuda-E. Caribbean Dollar           2.70     2021-09-30
#
#    Source Line Number  Fiscal Year  Fiscal Quarter Number  Calendar Year  \
# 0                   1         2021                      4           2021
# ...

# %%
USDollartoChineseKwan[USDollartoChineseKwan["Country"] == "China"]
# Out:
#    Record Date Country  Currency Country - Currency Description  \
# 37  2021-09-30   China  Renminbi                 China-Renminbi
#
#     Exchange Rate Effective Date  Source Line Number  Fiscal Year  \
# 37          6.463     2021-09-30                  38         2021
#
#     Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 37                      4           2021                        3
#
#     Calendar Month Number  Calendar Day Number
# 37                      9                   30

# %%
USDollartoChineseKwan1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/Foreign Currency Exchanges.csv")

# %%
USDollartoChineseKwan.head()
# Out:
#   Record Date            Country             Currency  \
# 0  2021-09-30        Afghanistan              Afghani
# 1  2021-09-30            Albania                  Lek
# 2  2021-09-30            Algeria                Dinar
# 3  2021-09-30             Angola               Kwanza
# 4  2021-09-30  Antigua & Barbuda  E. Caribbean Dollar
#
#           Country - Currency Description  Exchange Rate Effective Date  \
# 0                    Afghanistan-Afghani          87.88     2021-09-30
# 1                            Albania-Lek         104.80     2021-09-30
# 2                          Algeria-Dinar         136.61     2021-09-30
# 3                          Angola-Kwanza         598.65     2021-09-30
# 4  Antigua & Barbuda-E. Caribbean Dollar           2.70     2021-09-30
#
#    Source Line Number  Fiscal Year  Fiscal Quarter Number  Calendar Year  \
# 0                   1         2021                      4           2021
# ...

# %%
USDollartoChineseKwan1 = USDollartoChineseKwan1.iloc[5:,:]
USDollartoChineseKwan1.head()
# Out:
#    Series Description  \
# 10            2012-04
# 11            2012-05
# 12            2012-06
# 13            2012-07
# 14            2012-08
#
#    AUSTRALIA -- SPOT EXCHANGE RATE, US$/AUSTRALIAN $ RECIPROCAL OF RXI_N.M.AL   \
# 10                                             1.0350
# 11                                             0.9980
# 12                                             0.9986
# 13                                             1.0300
# 14                                             1.0475
#
#    SPOT EXCHANGE RATE - EURO AREA   \
# 10                          1.3160
# 11                          1.2806
# 12                          1.2541
# 13                          1.2278
# 14                          1.2406
#
#    NEW ZEALAND -- SPOT EXCHANGE RATE, US$/NZ$ (RECIPROCAL OF RXI_N.M.NZ)   \
# 10                                             0.8180
# 11                                             0.7748
# 12                                             0.7806
# ...

# %% [markdown]
# # South Korean Won

# %%
USDollartoSouthKoreanWon = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/RprtRateXchg_20210930_20210930.csv")

# %%
USDollartoSouthKoreanWon1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/Foreign Currency Exchanges.csv")

# %%
USDollartoChineseKwan[USDollartoChineseKwan["Country"] == "Korea"]
# Out:
#    Record Date Country Currency Country - Currency Description  Exchange Rate  \
# 93  2021-09-30   Korea      Won                      Korea-Won         1184.9
#
#    Effective Date  Source Line Number  Fiscal Year  Fiscal Quarter Number  \
# 93     2021-09-30                  94         2021                      4
#
#     Calendar Year  Calendar Quarter Number  Calendar Month Number  \
# 93           2021                        3                      9
#
#     Calendar Day Number
# 93                   30

# %%
USDollartoSouthKoreanWon1.head()
# Out:
#     Series Description  \
# 0                Unit:
# 1          Multiplier:
# 2            Currency:
# 3  Unique Identifier:
# 4          Time Period
#
#   AUSTRALIA -- SPOT EXCHANGE RATE, US$/AUSTRALIAN $ RECIPROCAL OF RXI_N.M.AL   \
# 0                                  Currency:_Per_AUD
# 1                                                  1
# 2                                                USD
# 3                              H10/H10/RXI$US_N.M.AL
# 4                                      RXI$US_N.M.AL
#
#   SPOT EXCHANGE RATE - EURO AREA   \
# 0               Currency:_Per_EUR
# 1                               1
# 2                             USD
# 3           H10/H10/RXI$US_N.M.EU
# 4                   RXI$US_N.M.EU
#
#   NEW ZEALAND -- SPOT EXCHANGE RATE, US$/NZ$ (RECIPROCAL OF RXI_N.M.NZ)   \
# 0                                  Currency:_Per_NZD
# 1                                                  1
# 2                                                USD
# ...

# %% [markdown]
# # North Korean Won

# %%
USDollartoNorthKoreanWon = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/RprtRateXchg_20210930_20210930.csv")

# %%
USDollartoNorthKoreanWon1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/Foreign Currency Exchanges.csv")

# %%
USDollartoNorthKoreanWon.head()
# Out:
#   Record Date            Country             Currency  \
# 0  2021-09-30        Afghanistan              Afghani
# 1  2021-09-30            Albania                  Lek
# 2  2021-09-30            Algeria                Dinar
# 3  2021-09-30             Angola               Kwanza
# 4  2021-09-30  Antigua & Barbuda  E. Caribbean Dollar
#
#           Country - Currency Description  Exchange Rate Effective Date  \
# 0                    Afghanistan-Afghani          87.88     2021-09-30
# 1                            Albania-Lek         104.80     2021-09-30
# 2                          Algeria-Dinar         136.61     2021-09-30
# 3                          Angola-Kwanza         598.65     2021-09-30
# 4  Antigua & Barbuda-E. Caribbean Dollar           2.70     2021-09-30
#
#    Source Line Number  Fiscal Year  Fiscal Quarter Number  Calendar Year  \
# 0                   1         2021                      4           2021
# ...

# %%
USDollartoNorthKoreanWon1.head()
# Out:
#     Series Description  \
# 0                Unit:
# 1          Multiplier:
# 2            Currency:
# 3  Unique Identifier:
# 4          Time Period
#
#   AUSTRALIA -- SPOT EXCHANGE RATE, US$/AUSTRALIAN $ RECIPROCAL OF RXI_N.M.AL   \
# 0                                  Currency:_Per_AUD
# 1                                                  1
# 2                                                USD
# 3                              H10/H10/RXI$US_N.M.AL
# 4                                      RXI$US_N.M.AL
#
#   SPOT EXCHANGE RATE - EURO AREA   \
# 0               Currency:_Per_EUR
# 1                               1
# 2                             USD
# 3           H10/H10/RXI$US_N.M.EU
# 4                   RXI$US_N.M.EU
#
#   NEW ZEALAND -- SPOT EXCHANGE RATE, US$/NZ$ (RECIPROCAL OF RXI_N.M.NZ)   \
# 0                                  Currency:_Per_NZD
# 1                                                  1
# 2                                                USD
# ...

# %% [markdown]
# # Euro

# %%
USDollartoEuropeanEuro = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/RprtRateXchg_20210930_20210930.csv")

# %%
USDollartoEuropeanEuro1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Rates/Currency Rate Exchange Data/Foreign Currency Exchanges.csv")

# %%
USDollartoEuropeanEuro[USDollartoEuropeanEuro["Currency"]==  "Euro"]
# Out:
#     Record Date       Country Currency Country - Currency Description  \
# 8    2021-09-30       Austria     Euro                   Austria-Euro
# 15   2021-09-30       Belgium     Euro                   Belgium-Euro
# 44   2021-09-30  Cross Border     Euro              Cross Border-Euro
# 47   2021-09-30        Cyprus     Euro                    Cyprus-Euro
# 59   2021-09-30       Estonia     Euro                   Estonia-Euro
# 61   2021-09-30     Euro Zone     Euro                 Euro Zone-Euro
# 63   2021-09-30       Finland     Euro                   Finland-Euro
# 64   2021-09-30        France     Euro                    France-Euro
# 68   2021-09-30       Germany     Euro                   Germany-Euro
# 70   2021-09-30        Greece     Euro                    Greece-Euro
# 85   2021-09-30       Ireland     Euro                   Ireland-Euro
# 87   2021-09-30         Italy     Euro                     Italy-Euro
# ...

# %%
USDollartoEuropeanEuro1.head()
# Out:
#     Series Description  \
# 0                Unit:
# 1          Multiplier:
# 2            Currency:
# 3  Unique Identifier:
# 4          Time Period
#
#   AUSTRALIA -- SPOT EXCHANGE RATE, US$/AUSTRALIAN $ RECIPROCAL OF RXI_N.M.AL   \
# 0                                  Currency:_Per_AUD
# 1                                                  1
# 2                                                USD
# 3                              H10/H10/RXI$US_N.M.AL
# 4                                      RXI$US_N.M.AL
#
#   SPOT EXCHANGE RATE - EURO AREA   \
# 0               Currency:_Per_EUR
# 1                               1
# 2                             USD
# 3           H10/H10/RXI$US_N.M.EU
# 4                   RXI$US_N.M.EU
#
#   NEW ZEALAND -- SPOT EXCHANGE RATE, US$/NZ$ (RECIPROCAL OF RXI_N.M.NZ)   \
# 0                                  Currency:_Per_NZD
# 1                                                  1
# 2                                                USD
# ...

# %% [markdown]
# # Canadian Dollar

# %%
 USDollartoCanadianDollar = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Foreign Currency Data 4/USDCAD-H1.csv")

# %%
USDollartoCanadianDollar1 = pd.read_csv("C:/Users/Administrator/OneDrive/Documents/DataScienceWork/DataScienceResearchData/Forex History Data 2/USDCAD-2000-2020-15m.csv")

# %%
USDollartoCanadianDollar.head()
# Out:
#          Date      Time  OpenBid  HighBid   LowBid  CloseBid  OpenAsk  \
# 0  01/03/2010  22:00:00  1.04626  1.05174  1.04585   1.04663  1.04666
# 1  01/03/2010  23:00:00  1.04663  1.04839  1.04653   1.04695  1.04734
# 2  01/04/2010  00:00:00  1.04695  1.04988  1.04689   1.04953  1.04756
# 3  01/04/2010  01:00:00  1.04953  1.05154  1.04909   1.04954  1.05016
# 4  01/04/2010  02:00:00  1.04954  1.04954  1.04499   1.04514  1.04995
#
#    HighAsk   LowAsk  CloseAsk  Total Ticks
# 0  1.05285  1.04651   1.04734          253
# 1  1.04890  1.04726   1.04756          537
# 2  1.05036  1.04740   1.05016          785
# 3  1.05205  1.04960   1.04995          659
# 4  1.04995  1.04550   1.04565          588

# %%
USDollartoCanadianDollar1.head()
